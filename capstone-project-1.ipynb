# %%
pwd
# Out:
# '/Users/haiming/Desktop/python-folder/2020-fall-ML/code'

# %% [markdown]
# # This notebook is for capstone project

# %%
import pandas as pd
import numpy as np 
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
